# %%
import pandas as pd

# %%
may2019 = pd.read_csv('data/2019_05_Maig_qualitat_aire_BCN.csv')

# %%
may2019
# Out:
#       CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0                  8  Barcelona             19  Barcelona        4
# 1                  8  Barcelona             19  Barcelona        4
# 2                  8  Barcelona             19  Barcelona        4
# 3                  8  Barcelona             19  Barcelona        4
# 4                  8  Barcelona             19  Barcelona        4
# ...              ...        ...            ...        ...      ...
# 1087               8  Barcelona             19  Barcelona       57
# 1088               8  Barcelona             19  Barcelona       57
# 1089               8  Barcelona             19  Barcelona       57
# 1090               8  Barcelona             19  Barcelona       57
# 1091               8  Barcelona             19  Barcelona       57
#
#       CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 0                    7  2019    5    1   2.0  ...   5.0    V   4.0    V   1.0
# ...

# %%
may2019['CODI_CONTAMINANT'].value_counts()
# Out:
# 12    196
# 8     196
# 7     196
# 14    140
# 10    140
# 6     112
# 1     112
# Name: CODI_CONTAMINANT, dtype: int64

# %%
may2019.drop(['CODI_PROVINCIA','PROVINCIA','CODI_MUNICIPI','MUNICIPI'], axis = 1, inplace = True)

# %%
may2019.rename(columns = {'CODI_CONTAMINANT':'POLLUTANT_CODE','ESTACIO':'STATION','ANY':'YEAR','MES':'MONTH','DIA':'DAY'}, inplace = True)

# %%
may2019
# Out:
#       STATION  POLLUTANT_CODE  YEAR  MONTH  DAY   H01 V01   H02 V02   H03  \
# 0           4               7  2019      5    1   2.0   V   1.0   V   2.0
# 1           4               7  2019      5    2   2.0   V   3.0   V   2.0
# 2           4               7  2019      5    3   1.0   V   1.0   V   1.0
# 3           4               7  2019      5    4   2.0   V   3.0   V   3.0
# 4           4               7  2019      5    5   3.0   V   2.0   V   2.0
# ...       ...             ...   ...    ...  ...   ...  ..   ...  ..   ...
# 1087       57              14  2019      5   27  29.0   V  38.0   V  47.0
# 1088       57              14  2019      5   28  64.0   V  64.0   V  58.0
# 1089       57              14  2019      5   29  48.0   V  46.0   V  58.0
# 1090       57              14  2019      5   30  47.0   V  54.0   V  46.0
# 1091       57              14  2019      5   31  21.0   V  19.0   V  26.0
#
#       ...   H20  V20   H21  V21   H22  V22   H23  V23   H24  V24
# ...
